# %%
import pandas as pd
import numpy as np

# %%
file_path = "transmission_pipeline.csv"
transmission_pipeline_df = pd.read_csv(file_path)
transmission_pipeline_df.head()
# Out:
#    facility_id                                      facility_name  \
# 0      1012420                  Algonquin Gas Transmission L.L.C.
# 1      1012420                  Algonquin Gas Transmission L.L.C.
# 2      1012420                  Algonquin Gas Transmission L.L.C.
# 3      1013856                               Atmos Pipeline Texas
# 4      1012139  Eastern Gas Transmission and Storage - Transmi...
#
#            state  primary_naics_code industry_type_subpart  \
# 0    Connecticut              486210               W-TRANS
# 1  Massachusetts              486210               W-TRANS
# 2       New York              486210               W-TRANS
# 3          Texas              486210               W-TRANS
# 4       Maryland              486210               W-TRANS
#
#    total_emissions_2020  total_emissions_2019  total_emissions_2018  \
# 0           1036.700000           7735.400000            717.300000
# 1            337.400000           3347.650000             23.000000
# 2             39.500000           4692.150000           7092.200000
# 3          84077.619496         112132.022704         204567.940066
# 4             18.411694           5813.273205           3140.966538
#
#    total_emissions_2017  total_emissions_2016
# 0          10773.150000           1264.250000
# 1            264.550000           7515.450000
# 2           1551.050000          24960.050000
# 3         146756.129584         115793.676329
# 4          11012.495114           5261.786329

# %%
transmission_pipeline_df = transmission_pipeline_df[['industry_type_subpart', 'total_emissions_2020', 'total_emissions_2019', 'total_emissions_2018',
       'total_emissions_2017', 'total_emissions_2016']]
transmission_pipeline_df
# Out:
#    industry_type_subpart  total_emissions_2020  total_emissions_2019  \
# 0                W-TRANS           1036.700000           7735.400000
# 1                W-TRANS            337.400000           3347.650000
# 2                W-TRANS             39.500000           4692.150000
# 3                W-TRANS          84077.619496         112132.022704
# 4                W-TRANS             18.411694           5813.273205
# ..                   ...                   ...                   ...
# 86               W-TRANS           3034.651036           6509.719507
# 87               W-TRANS           1659.356127          17293.850499
# 88               W-TRANS          16747.890983           1956.785206
# 89               W-TRANS          10246.351914           4194.769794
# 90               W-TRANS             16.069715            493.688678
#
#     total_emissions_2018  total_emissions_2017  total_emissions_2016
# 0             717.300000          10773.150000           1264.250000
# 1              23.000000            264.550000           7515.450000
# 2            7092.200000           1551.050000          24960.050000
# 3          204567.940066         146756.129584         115793.676329
# 4            3140.966538          11012.495114           5261.786329
# ..                   ...                   ...                   ...
# 86           4107.802184           1745.133200              3.750000
# 87          11950.274251          11837.551500            143.450000
# 88          22556.347183          14303.532700          16735.800000
# 89          20602.288714          22026.786300          43863.000000
# 90           2154.114097           4705.401500          10019.040000
#
# [91 rows x 6 columns]

# %%
avg_transmission_pipeline_emissions2020 = transmission_pipeline_df["total_emissions_2020"].mean()
avg_transmission_pipeline_emissions2019 = transmission_pipeline_df["total_emissions_2019"].mean()
avg_transmission_pipeline_emissions2018 = transmission_pipeline_df["total_emissions_2018"].mean()
avg_transmission_pipeline_emissions2017 = transmission_pipeline_df["total_emissions_2017"].mean()
avg_transmission_pipeline_emissions2016 = transmission_pipeline_df["total_emissions_2016"].mean()

# %%
data = {'year': ['2020', '2019', '2018', '2017', '2016'],
        'avg_emissions': [avg_transmission_pipeline_emissions2020, avg_transmission_pipeline_emissions2019, avg_transmission_pipeline_emissions2018, avg_transmission_pipeline_emissions2017,
                         avg_transmission_pipeline_emissions2016]}
yearly_avg_df = pd.DataFrame(data)
yearly_avg_df
# Out:
#    year  avg_emissions
# 0  2020   24952.554642
# 1  2019   23616.831336
# 2  2018   17969.672849
# 3  2017   21788.997478
# 4  2016   29202.746049

# %%
yearly_avg_df.sort_values(by=['year'], inplace=True)
yearly_avg_df
# Out:
#    year  avg_emissions
# 4  2016   29202.746049
# 3  2017   21788.997478
# 2  2018   17969.672849
# 1  2019   23616.831336
# 0  2020   24952.554642

# %%
import matplotlib.pyplot as plot

# %%
yearly_avg_df.plot.bar(x="year", y="avg_emissions")
# Out:
# <AxesSubplot:xlabel='year'>
