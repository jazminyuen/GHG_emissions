# %%
import numpy as np
import pandas as pd
import plotly.express as px
import sqlalchemy as sa
from sqlalchemy import create_engine, text

# %%
db_string = 'postgresql://ghg_emissions:Password00@ghgemissions.cg3dqiowwhnr.us-west-1.rds.amazonaws.com:5432/ghg_data'
engine = create_engine(db_string)

# %%
query = """
SELECT * FROM direct_emissions
"""

# %%
df = pd.read_sql(query,engine)
df.head()
# Out:
#    facility_id                   facility_name         city state  zip_code  \
# 0      1004377  121 REGIONAL DISPOSAL FACILITY      MELISSA    TX     75454
# 1      1000112                    23rd and 3rd     BROOKLYN    NY     11232
# 2      1003742            31st Street Landfill  WESTCHESTER    IL     60154
# 3      1003188                    3M BROWNWOOD    BROWNWOOD    TX     76801
# 4      1005043                           3M CO    MAPLEWOOD    MN     55144
#
#    primary_naics_code industry_type_subpart industry_type_sector  \
# 0              562212                    HH                Waste
# 1              221112                   C,D         Power Plants
# 2              562212                  C,HH                Waste
# 3              326113                   C,N             Minerals
# 4              541715                     C                Other
#
#    total_emissions_2020  total_emissions_2019  total_emissions_2018  \
# ...

# %%
# Create total emissions df
em_df = pd.DataFrame(df[["total_emissions_2011",
                                "total_emissions_2012",
                                "total_emissions_2013",
                                "total_emissions_2014",
                                "total_emissions_2015",
                                "total_emissions_2016",
                                "total_emissions_2017",
                                "total_emissions_2018",
                                "total_emissions_2019",
                                "total_emissions_2020",
                                "industry_type_sector"]])
em_df.head()
# Out:
#    total_emissions_2011  total_emissions_2012  total_emissions_2013  \
# 0            194000.000            204000.000            289953.250
# 1            100591.828             68984.744            102599.220
# 2             95113.250             87357.750             97467.500
# 3             37149.360             33671.924             34821.820
# 4             76373.372             72407.026             80335.194
#
#    total_emissions_2014  total_emissions_2015  total_emissions_2016  \
# 0            241883.500            199011.750            221014.750
# 1             40722.200             67399.252             66797.352
# 2            120707.350             92696.600            120657.600
# 3             36419.864             36754.712             31773.480
# 4             81855.400             79440.076             79174.000
#
#    total_emissions_2017  total_emissions_2018  total_emissions_2019  \
# 0            250497.500            653854.000            518680.250
# ...

# %%
em_df = em_df.rename(columns={"total_emissions_2011":"2011",
                                "total_emissions_2012":"2012",
                                "total_emissions_2013":"2013",
                                "total_emissions_2014":"2014",
                                "total_emissions_2015":"2015",
                                "total_emissions_2016":"2016",
                                "total_emissions_2017":"2017",
                                "total_emissions_2018":"2018",
                                "total_emissions_2019":"2019",
                                "total_emissions_2020":"2020",
                                "industry_type_sector":"Sector"})
em_df
# Out:
#             2011         2012        2013        2014         2015  \
# 0     194000.000   204000.000  289953.250  241883.500   199011.750
# 1     100591.828    68984.744  102599.220   40722.200    67399.252
# 2      95113.250    87357.750   97467.500  120707.350    92696.600
# 3      37149.360    33671.924   34821.820   36419.864    36754.712
# 4      76373.372    72407.026   80335.194   81855.400    79440.076
# ...          ...          ...         ...         ...          ...
# 5287   58893.092    83978.982   56638.910   40266.614    54812.054
# 5288  786899.532  1263260.168  617747.712  875180.356  1465347.020
# 5289   66811.452    78032.512   70492.840   41118.262    82924.594
# 5290   31193.236    28339.044   31493.184   23916.312    23648.012
# 5291   38540.000    39733.000   40838.000   41921.350    49400.750
#
#              2016         2017         2018         2019         2020  \
# 0      221014.750   250497.500   653854.000   518680.250   504064.000
# ...

# %%
# Create summary_df
summary = em_df.describe()
summary_df = pd.DataFrame(summary)
summary_df
# Out:
#                2011          2012          2013          2014          2015  \
# count  5.292000e+03  5.292000e+03  5.292000e+03  5.292000e+03  5.292000e+03
# mean   5.421853e+05  5.253794e+05  5.276940e+05  5.300132e+05  5.074392e+05
# std    1.658999e+06  1.547694e+06  1.586747e+06  1.578584e+06  1.451785e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00 -1.196250e+03
# 25%    4.266365e+04  4.264024e+04  4.101131e+04  4.072911e+04  4.047601e+04
# 50%    8.291325e+04  8.143777e+04  7.906603e+04  7.963643e+04  7.981761e+04
# 75%    2.447105e+05  2.569984e+05  2.377225e+05  2.391493e+05  2.460063e+05
# max    2.207365e+07  2.181556e+07  2.229333e+07  2.048246e+07  1.924705e+07
#
#                2016          2017          2018          2019          2020
# count  5.292000e+03  5.292000e+03  5.292000e+03  5.292000e+03  5.292000e+03
# mean   4.906756e+05  4.760750e+05  4.882045e+05  4.600705e+05  4.194801e+05
# ...

# %%
# Flip columns and rows
summary_df = summary_df.transpose()
summary_df
# Out:
#        count           mean           std      min           25%        50%  \
# 2011  5292.0  542185.261530  1.658999e+06     0.00  42663.654194  82913.250
# 2012  5292.0  525379.352896  1.547694e+06     0.00  42640.236000  81437.770
# 2013  5292.0  527694.002509  1.586747e+06     0.00  41011.311500  79066.033
# 2014  5292.0  530013.182516  1.578584e+06     0.00  40729.115000  79636.430
# 2015  5292.0  507439.182867  1.451785e+06 -1196.25  40476.013500  79817.608
# 2016  5292.0  490675.585342  1.408732e+06     0.00  39404.548500  78308.078
# 2017  5292.0  476074.979441  1.402010e+06     0.00  38282.046000  76286.003
# 2018  5292.0  488204.499234  1.402197e+06     0.00  39675.300000  80118.275
# 2019  5292.0  460070.494244  1.289690e+06     0.00  39147.953500  77823.631
# 2020  5292.0  419480.113297  1.157767e+06     0.00  35523.691000  72030.608
#
#               75%           max
# 2011  244710.5025  2.207365e+07
# 2012  256998.4475  2.181556e+07
# 2013  237722.4540  2.229333e+07
# ...

# %%
# Get sum of emissions per year and append to summary_df
summary_df["sum"] = em_df.sum().to_list()
summary_df
# Out:
#        count           mean           std      min           25%        50%  \
# 2011  5292.0  542185.261530  1.658999e+06     0.00  42663.654194  82913.250
# 2012  5292.0  525379.352896  1.547694e+06     0.00  42640.236000  81437.770
# 2013  5292.0  527694.002509  1.586747e+06     0.00  41011.311500  79066.033
# 2014  5292.0  530013.182516  1.578584e+06     0.00  40729.115000  79636.430
# 2015  5292.0  507439.182867  1.451785e+06 -1196.25  40476.013500  79817.608
# 2016  5292.0  490675.585342  1.408732e+06     0.00  39404.548500  78308.078
# 2017  5292.0  476074.979441  1.402010e+06     0.00  38282.046000  76286.003
# 2018  5292.0  488204.499234  1.402197e+06     0.00  39675.300000  80118.275
# 2019  5292.0  460070.494244  1.289690e+06     0.00  39147.953500  77823.631
# 2020  5292.0  419480.113297  1.157767e+06     0.00  35523.691000  72030.608
#
#               75%           max           sum
# 2011  244710.5025  2.207365e+07  2.869244e+09
# ...

# %%
summary_df.columns
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max', 'sum'], dtype='object')

# %%
summary_df.rename(columns={'25%':'first_q', '50%':'median', '75%':'third_q',}, inplace=True)

# %%
summary_df.columns
# Out:
# Index(['count', 'mean', 'std', 'min', 'first_q', 'median', 'third_q', 'max',
#        'sum'],
#       dtype='object')

# %%
summary_df.to_csv("summary.csv")

# %%
# Test average line chart
fig = px.line(summary_df, y="mean", title="Average Total Emissions",labels={"index":"Year","mean":"Mean"})
fig.show()
# Out:
# <div>                            <div id="491244dc-1fd3-44d4-80f8-942e9f91f987" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("491244dc-1fd3-44d4-80f8-942e9f91f987")) {                    Plotly.newPlot(                        "491244dc-1fd3-44d4-80f8-942e9f91f987",                        [{"hovertemplate":"Year=%{x}<br>Mean=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"xaxis":"x","y":[542185.2615304897,525379.3528962113,527694.0025094533,530013.1825155249,507439.1828665908,490675.5853423914,476074.97944074695,488204.4992340004,460070.49424415914,419
# ...

# %%
# Test median line chart
fig = px.line(summary_df, y="median", title="Median Total Emissions", labels={"median": "Median", "index":"Year"})
fig.show()
# Out:
# <div>                            <div id="68f113da-6bb0-433d-86fa-7688de168d60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68f113da-6bb0-433d-86fa-7688de168d60")) {                    Plotly.newPlot(                        "68f113da-6bb0-433d-86fa-7688de168d60",                        [{"hovertemplate":"Year=%{x}<br>Median=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"xaxis":"x","y":[82913.25,81437.77,79066.033,79636.43,79817.60800000001,78308.07800000001,76286.003,80118.275,77823.631,72030.60800000001],"yaxis":"y","type":"scatter"}],            
# ...

# %%
# Test sum line chart
fig = px.line(summary_df, y="sum", title="Sum of Total Emissions",labels={"index":"Year","sum":"Total Emissions"})
fig.show()
# Out:
# <div>                            <div id="858dd3ce-32e3-4860-b7cf-b091d0b7322e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("858dd3ce-32e3-4860-b7cf-b091d0b7322e")) {                    Plotly.newPlot(                        "858dd3ce-32e3-4860-b7cf-b091d0b7322e",                        [{"hovertemplate":"Year=%{x}<br>Total Emissions=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"xaxis":"x","y":[2869244404.019355,2780307535.5267572,2792556661.2800226,2804829761.872161,2685368155.7300043,2596655197.6319385,2519388791.2004304,2583578209.9463267,243469
# ...

# %% [markdown]
# ### Get emissions by sector and by year

# %%
em_df.to_csv("sector_emissions.csv", index=False)

# %%
# Sectors with the most facilities
top_sectors = [em_df["Sector"].value_counts()]
top_sectors = pd.DataFrame(top_sectors)
top_sectors.columns
# Out:
# Index(['Power Plants', 'Waste', 'Other', 'Petroleum and Natural Gas Systems',
#        'Minerals', 'Chemicals', 'Metals', 'Pulp and Paper', 'Other,Waste',
#        'Pulp and Paper,Waste',
#        'Natural Gas and Natural Gas Liquids Suppliers,Petroleum and Natural Gas Systems',
#        'Petroleum Product Suppliers,Refineries',
#        'Chemicals,Petroleum Product Suppliers,Refineries',
#        'Other,Suppliers of CO2', 'Chemicals,Suppliers of CO2', 'Metals,Waste',
#        'Chemicals,Industrial Gas Suppliers', 'Other,Suppliers of CO2,Waste',
#        'Chemicals,Waste', 'Minerals,Waste', 'Other,Power Plants',
#        'Petroleum and Natural Gas Systems,Suppliers of CO2', 'Refineries',
#        'Power Plants,Waste',
#        'Import and Export of Equipment Containing Fluorintaed GHGs,Other',
#        'Injection of CO2,Petroleum and Natural Gas Systems,Suppliers of CO2',
#        'Injection of CO2,Petroleum and Natural Gas Systems',
# ...

# %%
table1 = {'Sector':df['industry_type_sector'], 'Emissions':df["total_emissions_2020"]}
sector_2020 = pd.DataFrame(table1)
sector_2020
# Out:
#                                  Sector    Emissions
# 0                                 Waste   504064.000
# 1                          Power Plants    60819.700
# 2                                 Waste   100500.948
# 3                              Minerals    29359.640
# 4                                 Other    82308.238
# ...                                 ...          ...
# 5287  Petroleum and Natural Gas Systems    15072.952
# 5288                       Power Plants  1780786.552
# 5289                       Power Plants   325679.418
# 5290                       Power Plants        0.000
# 5291                              Waste    89476.750
#
# [5292 rows x 2 columns]

# %%
fig = px.bar(sector_2020, x='Sector', y='Emissions')
fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5, opacity=0.6)
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>                            <div id="6079819f-9709-416e-80bc-91410b7a3af8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6079819f-9709-416e-80bc-91410b7a3af8")) {                    Plotly.newPlot(                        "6079819f-9709-416e-80bc-91410b7a3af8",                        [{"alignmentgroup":"True","hovertemplate":"Sector=%{x}<br>Emissions=%{y}<extra></extra>","legendgroup":"","marker":{"color":"rgb(158,202,225)","pattern":{"shape":""},"line":{"color":"rgb(8,48,107)","width":1.5}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Waste","Power Plants","Waste","Minerals","Other","Minerals","Other","Chemicals,Industrial Gas Suppliers","Chemicals,Industrial Gas Suppliers","Chemicals,Industrial 
# ...

# %%
# Get power plant emissions by year df.drop(['B', 'C'], axis=1)
pp_df = em_df.loc[em_df["Sector"]=="Power Plants"]
pp_df.head()
# Out:
#            2011         2012         2013         2014         2015  \
# 1    100591.828    68984.744   102599.220    40722.200    67399.252
# 14   265415.758   199034.550   206935.342   262718.648   238778.194
# 16   297071.804   148328.410   226196.740   272983.418   255020.780
# 17  2270617.680  2538211.824  2556867.744  3143355.920  2663665.556
# 30   108163.192    89412.964   100435.022   109183.288    94984.492
#
#            2016         2017         2018         2019         2020  \
# 1     66797.352    52698.656    70705.288    44658.384    60819.700
# 14   232873.708   218874.796   260405.936   224910.106   149968.982
# 16   205696.230   194944.188   270795.330   254385.114   174902.712
# 17  2315093.224  2172917.248  2741626.714  2789540.744  2386473.354
# 30    93656.996    95251.540   100988.820    81392.592    85831.676
#
#           Sector
# 1   Power Plants
# 14  Power Plants
# 16  Power Plants
# 17  Power Plants
# 30  Power Plants

# %%
pp_df.drop(["Sector"], axis=1, inplace=True)
pp_df
# Out:
# /Users/jaz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              2011         2012         2013         2014         2015  \
# 1      100591.828    68984.744   102599.220    40722.200    67399.252
# 14     265415.758   199034.550   206935.342   262718.648   238778.194
# 16     297071.804   148328.410   226196.740   272983.418   255020.780
# 17    2270617.680  2538211.824  2556867.744  3143355.920  2663665.556
# 30     108163.192    89412.964   100435.022   109183.288    94984.492
# ...           ...          ...          ...          ...          ...
# 5284     8157.520    29212.292    23021.112    16106.340    15024.492
# 5285   232147.832   165258.016   215740.944   232060.330   222752.422
# ...

# %%
pp_df.columns
# Out:
# Index(['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020'],
#       dtype='object')

# %%
pp_sum = pp_df.sum(axis=0).tolist()
year = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
       '2020']

# %%
fig = px.bar(x=year,y=pp_sum, title="Power Plant Emissions", labels={'y':'Emissions', 'x':'Year'})
fig.show()
# Out:
# <div>                            <div id="6de31c3f-d5a7-4b35-aaaf-693340196a60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6de31c3f-d5a7-4b35-aaaf-693340196a60")) {                    Plotly.newPlot(                        "6de31c3f-d5a7-4b35-aaaf-693340196a60",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}<br>Emissions=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"],"xaxis":"x","y":[1884268830.8130755,1807839135.579,1818491191.9112384,1819919213.767303,1725120457.7083187,1651032197.845931,1572005190.310207,1613680
# ...

# %% [markdown]
# ### Get top sectors with the most facilities for dropdown menu in app.
# ### Choose sector, show total emissions by year
# ####
#
# 'Power Plants', 'Waste', 'Other', 'Petroleum and Natural Gas Systems',
#        'Minerals', 'Chemicals', 'Metals', 'Pulp and Paper', 'Other,Waste',
#        'Pulp and Paper,Waste',
#        'Natural Gas and Natural Gas Liquids Suppliers,Petroleum and Natural Gas Systems',
#        'Petroleum Product Suppliers,Refineries'

# %%
# Sector sum function
year = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
       '2020'] 
def sector_sum(sector):
    df = em_df.loc[em_df["Sector"]==sector]
    df.drop(["Sector"], axis=1, inplace=True)
    sum = df.sum(axis=0).tolist()
    return sum

# %%
# Test function
sector_sum('Petroleum and Natural Gas Systems')
# Out:
# /Users/jaz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [67188101.97299999,
#  67432251.892,
#  64566704.68000001,
#  62580893.561,
#  61040477.587919995,
#  61283215.024000004,
#  62448828.692,
#  66846910.96848787,
#  67888737.42628683,
#  60870633.84484909]

# %%
# Sector mean function
year = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
       '2020'] 
def sector_mean(sector):
    df = em_df.loc[em_df["Sector"]==sector]
    df.drop(["Sector"], axis=1, inplace=True)
    mean = df.mean(axis=0).tolist()
    return mean

# %%
sector_mean('Power Plants')
# Out:
# [1620179.5621780495,
#  1554461.853464315,
#  1563620.9732684768,
#  1564848.8510466912,
#  1483336.5930424063,
#  1419632.1563593547,
#  1351681.1610577877,
#  1387515.2922945137,
#  1278019.1941160671,
#  1143667.1146312777]

# %%
# Testing connection to database, sector_emissions table
db_string = 'postgresql://ghg_emissions:Password00@ghgemissions.cg3dqiowwhnr.us-west-1.rds.amazonaws.com:5432/ghg_data'
engine = create_engine(db_string)
query = text('SELECT * FROM sector_emissions')
df = pd.read_sql(query,engine)
df.head()
# Out:
#         _2011       _2012       _2013       _2014       _2015       _2016  \
# 0  194000.000  204000.000  289953.250  241883.500  199011.750  221014.750
# 1  100591.828   68984.744  102599.220   40722.200   67399.252   66797.352
# 2   95113.250   87357.750   97467.500  120707.350   92696.600  120657.600
# 3   37149.360   33671.924   34821.820   36419.864   36754.712   31773.480
# 4   76373.372   72407.026   80335.194   81855.400   79440.076   79174.000
#
#         _2017       _2018       _2019       _2020        sector
# 0  250497.500  653854.000  518680.250  504064.000         Waste
# 1   52698.656   70705.288   44658.384   60819.700  Power Plants
# 2   29026.800   31220.150   18925.400  100500.948         Waste
# 3   36202.264   34432.420   30571.636   29359.640      Minerals
# 4   76595.410  104995.534  106258.176   82308.238         Other

# %%
em_df = df.rename(columns={"_2011":"2011","_2012":"2012","_2013":"2013","_2014":"2014","_2015":"2015","_2016":"2016","_2017":"2017","_2018":"2018","_2019":"2019","_2020":"2020","sector":"Sector"})

# %%
# Testing connection to database, summary table
query_summary = text('SELECT * FROM summary')
summary_df = pd.read_sql(query_summary, engine)
summary_df.head()
# Out:
#    year   count           mean           std      min       first_q  \
# 0  2011  5292.0  542185.261530  1.658999e+06     0.00  42663.654194
# 1  2012  5292.0  525379.352896  1.547694e+06     0.00  42640.236000
# 2  2013  5292.0  527694.002509  1.586747e+06     0.00  41011.311500
# 3  2014  5292.0  530013.182516  1.578584e+06     0.00  40729.115000
# 4  2015  5292.0  507439.182867  1.451785e+06 -1196.25  40476.013500
#
#       median      third_q           max           sum
# 0  82913.250  244710.5025  2.207365e+07  2.869244e+09
# 1  81437.770  256998.4475  2.181556e+07  2.780308e+09
# 2  79066.033  237722.4540  2.229333e+07  2.792557e+09
# 3  79636.430  239149.2615  2.048246e+07  2.804830e+09
# 4  79817.608  246006.2885  1.924705e+07  2.685368e+09

# %%
def update_summary_chart(stat):
    fig = px.line(summary_df, x="year", y=f"{stat}", labels={"year":"Year"})
    return fig

# %%
summary_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/wn/6xp4hzf11dbf37f0z_165gdr0000gn/T/ipykernel_93004/1127002372.py in <module>
# ----> 1 update_summary_chart(summary_df[mean])
#
# NameError: name 'mean' is not defined
