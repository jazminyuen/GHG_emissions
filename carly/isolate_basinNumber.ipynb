# %%
import pandas as pd

# %%
df = pd.read_csv('gather_boost.csv')

# %%
df
# Out:
#      facility_id                                facility_name  \
# 0        1012156    260 - East Texas Basin Gathering/Boosting
# 1        1012353                     430 Permian Basin GB DEC
# 2        1012154      580 - San Juan Basin Gathering/Boosting
# 3        1012251                        ALLP Greenriver Basin
# 4        1012248                             ALLP Uinta Basin
# ..           ...                                          ...
# 254      1012568            XTO Energy Inc 395 Williston – GB
# 255      1012545               XTO Energy Inc 415 Strawn – GB
# 256      1012544  XTO Energy Inc 420 Fort Worth Syncline – GB
# 257      1012541              XTO Energy Inc 430 Permian – GB
# 258      1012581             XTO Energy Inc 595 Piceance – GB
#
#                          basin           city state  zip_code  \
# 0       260 - East Texas Basin        Houston    TX     77079
# 1          430 - Permian Basin  Oklahoma City    OK     73102
# ...

# %%
basins = df['basin'].tolist()
#basins = [str(x) for x in basins] (not sure if this line is needed. was getting typeError in another notebook, but doesnt seem to be a problem here)

# %%
basin_num = []

for basin in basins:
    x = basin.split()
    print(x)
    basin_num.append(x[0])
# Out:
# ['260', '-', 'East', 'Texas', 'Basin']
# ['430', '-', 'Permian', 'Basin']
# ['580', '-', 'San', 'Juan', 'Basin']
# ['535', '-', 'Green', 'River', 'Basin']
# ['575', '-', 'Uinta', 'Basin']
# ['345', '-', 'Arkoma', 'Basin']
# ['740', '-', 'Coastal', 'Basins']
# ['745', '-', 'San', 'Joaquin', 'Basin']
# ['540', '-', 'Denver', 'Basin']
# ['160', '-', 'Appalachian', 'Basin']
# ['160A', '-', 'Appalachian', 'Basin', '(Eastern', 'Overthrust', 'Area)']
# ['160A', '-', 'Appalachian', 'Basin', '(Eastern', 'Overthrust', 'Area)']
# ['160A', '-', 'Appalachian', 'Basin', '(Eastern', 'Overthrust', 'Area)']
# ['160A', '-', 'Appalachian', 'Basin', '(Eastern', 'Overthrust', 'Area)']
# ['220', '-', 'Gulf', 'Coast', 'Basin', '(LA,', 'TX)']
# ['220', '-', 'Gulf', 'Coast', 'Basin', '(LA,', 'TX)']
# ['430', '-', 'Permian', 'Basin']
# ['540', '-', 'Denver', 'Basin']
# ['540', '-', 'Denver', 'Basin']
# ['575', '-', 'Uinta', 'Basin']
# ['230', '-', 'Arkla', 'Basin']
# ['345', '-', 'Arkoma', 'Basin']
# ...

# %%
df['basin_num'] = basin_num

# %%
df
# Out:
#      facility_id                                facility_name  \
# 0        1012156    260 - East Texas Basin Gathering/Boosting
# 1        1012353                     430 Permian Basin GB DEC
# 2        1012154      580 - San Juan Basin Gathering/Boosting
# 3        1012251                        ALLP Greenriver Basin
# 4        1012248                             ALLP Uinta Basin
# ..           ...                                          ...
# 254      1012568            XTO Energy Inc 395 Williston – GB
# 255      1012545               XTO Energy Inc 415 Strawn – GB
# 256      1012544  XTO Energy Inc 420 Fort Worth Syncline – GB
# 257      1012541              XTO Energy Inc 430 Permian – GB
# 258      1012581             XTO Energy Inc 595 Piceance – GB
#
#                          basin           city state  zip_code  \
# 0       260 - East Texas Basin        Houston    TX     77079
# 1          430 - Permian Basin  Oklahoma City    OK     73102
# ...
