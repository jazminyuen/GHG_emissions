# %%
import pandas as pd
import numpy as np

# %%
gather_boost_raw_df = pd.read_excel('gather_boost_raw.xlsx', header = 3)

# %%
gather_boost_raw_df
# Out:
#      Facility Id        FRS Id  \
# 0        1012156  1.100701e+11
# 1        1012155  1.100701e+11
# 2        1013937  1.100709e+11
# 3        1013815  1.100702e+11
# 4        1012353  1.100702e+11
# ..           ...           ...
# 408      1012541  1.100157e+11
# 409      1012577  1.100701e+11
# 410      1012588  1.100701e+11
# 411      1012581  1.100701e+11
# 412      1013573  1.100707e+11
#
#                                          Facility Name  \
# 0            260 - East Texas Basin Gathering/Boosting
# 1                345 - Arkoma Basin Gathering/Boosting
# 2    3Bear - 430 - Permian Basin Gathering and Boos...
# 3                            430 Cotton Draw Midstream
# 4                             430 Permian Basin GB DEC
# ..                                                 ...
# 408                    XTO Energy Inc 430 Permian – GB
# 409                     XTO Energy Inc 575 Uintah – GB
# 410                   XTO Energy Inc 580 San Juan – GB
# ...

# %%
gather_boost_df = gather_boost_raw_df.drop(['FRS Id', 'Reported Address', 'Reported County', 'Reported Latitude', 'Reported Longitude'], axis=1)

# %%
gather_boost_df
# Out:
#      Facility Id                                      Facility Name  \
# 0        1012156          260 - East Texas Basin Gathering/Boosting
# 1        1012155              345 - Arkoma Basin Gathering/Boosting
# 2        1013937  3Bear - 430 - Permian Basin Gathering and Boos...
# 3        1013815                          430 Cotton Draw Midstream
# 4        1012353                           430 Permian Basin GB DEC
# ..           ...                                                ...
# 408      1012541                    XTO Energy Inc 430 Permian – GB
# 409      1012577                     XTO Energy Inc 575 Uintah – GB
# 410      1012588                   XTO Energy Inc 580 San Juan – GB
# 411      1012581                   XTO Energy Inc 595 Piceance – GB
# 412      1013573                            XcL Midstream Operating
#
#                                                  Basin  Reported City  \
# 0                               260 - East Texas Basin        Houston
# ...

# %%
# Rename the columns
col_names = {'Facility Id': 'facility_id', 
             'Facility Name': 'facility_name', 
             'Basin': 'basin', 
             'Reported City': 'city', 
             'Reported State': 'state', 
             'Reported Zip Code': 'zip_code',
             'Primary NAICS Code': 'primary_naics_code',
       'Latest Reported Industry Type (subparts)': 'industry_type_subpart',
       '2020 Total reported emissions from Onshore Oil & Gas Production ': 'total_emissions_2020',
       '2019 Total reported emissions from Onshore Oil & Gas Production ': 'total_emissions_2019',
       '2018 Total reported emissions from Onshore Oil & Gas Production ': 'total_emissions_2018',
       '2017 Total reported emissions from Onshore Oil & Gas Production ': 'total_emissions_2017',
       '2016 Total reported emissions from Onshore Oil & Gas Production ': 'total_emissions_2016'}
gather_boost_df.rename(columns=col_names, inplace=True)

# %%
gather_boost_df
# Out:
#      facility_id                                      facility_name  \
# 0        1012156          260 - East Texas Basin Gathering/Boosting
# 1        1012155              345 - Arkoma Basin Gathering/Boosting
# 2        1013937  3Bear - 430 - Permian Basin Gathering and Boos...
# 3        1013815                          430 Cotton Draw Midstream
# 4        1012353                           430 Permian Basin GB DEC
# ..           ...                                                ...
# 408      1012541                    XTO Energy Inc 430 Permian – GB
# 409      1012577                     XTO Energy Inc 575 Uintah – GB
# 410      1012588                   XTO Energy Inc 580 San Juan – GB
# 411      1012581                   XTO Energy Inc 595 Piceance – GB
# 412      1013573                            XcL Midstream Operating
#
#                                                  basin           city state  \
# ...

# %%
# Check datatypes
gather_boost_df.dtypes
# Out:
# facility_id                                                   int64
# facility_name                                                object
# basin                                                        object
# city                                                         object
# state                                                        object
# zip_code                                                      int64
# primary_naics_code                                            int64
# industry_type_subpart                                        object
# 2020 Total reported emissions from Gathering & Boosting     float64
# 2019 Total reported emissions from Gathering & Boosting     float64
# 2018 Total reported emissions from Gathering & Boosting     float64
# 2017 Total reported emissions from Gathering & Boosting     float64
# 2016 Total reported emissions from Gathering & Boosting     float64
# dtype: object

# %%
## Export to CSV without the index
#df.to_csv('gather_boost.csv', index=False)
